# %%
import pandas as pd
import datetime
import re


# 1
def df_nan_filter(df):
    """Apply filters on NaN values
    Args:
        df: pandas dataframe.
    Returns:
        Filtered Dataframe.
    Raises:
        This function shouldn't raise any Exception.
    """
    df.dropna(subset=['Size'], inplace=True)
    df['Languages'].fillna(value="EN", inplace=True)
    df['Price'].fillna(value=0.0, inplace=True)
    avg = df['Average User Rating'].notna().mean()
    df['Average User Rating'].fillna(value=avg, inplace=True)
    df['User Rating Count'].fillna(value=1, inplace=True)
    return df


# 2
def change_date_format(date: str):
    """Change date format from dd/mm/yyyy to yyyy-mm-dd
    Args:
        date: a string representing the date.
    Returns:
        The date in the format yyyy-mm-dd.
    Raises:
        This function shouldn't raise any Exception.
    """
    try:
        newdate = datetime.datetime.strptime(date, '%d/%m/%Y')
        newdate = newdate.strftime('%Y/%m/%d')
        return newdate
    except():
        return date


def string_filter(s: str):
    """Apply filters in order to clean the string.
    Args:
      s: string.
    Returns:
      Filtered String.
    Raises:
      This function shouldn't raise any Exception.
    """
    # filter : \\t, \\n, \\U1a1b2c3d4, \\u1a2b, \\x1a
    # turn \' into '
    # replace remaining \\ with \
    # turn multiple spaces into one space
    s = re.sub(r'''\\+(t|n|U[a-z0-9]{8}|u[a-z0-9]{4}|x[a-z0-9]{2}|[\.]{2})''', ' ', s)
    s = s.replace('\\\'', '\'').replace('\\\\', '\\')
    s = re.sub(r' +', ' ', s)
    return (s)

# %%
df = pd.read_csv('../appstore_games.csv')
# 1
dff = df_nan_filter(df)
# 2
dff["Original Release Date"] = dff["Original Release Date"].apply(lambda x: change_date_format(x))
# 3
dff["Description"] = dff["Description"].apply(lambda x: string_filter(x))
# 4
dff.drop_duplicates(subset=df.columns[0], inplace=True)
# 5
dff['Age Rating'] = dff['Age Rating'].apply(lambda x: re.findall(r'\d+', x)[0] )
dff['User Rating Count'] = pd.to_numeric(dff['User Rating Count'], downcast='integer')
dff['Size'] = pd.to_numeric(dff['Size'], downcast='integer')
# 6
indexNames = dff[ dff['Name'].apply(len) < 4 ].index
dff.drop(indexNames, inplace=True)

# %%
dff
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# 1                        Reversi                             NaN
# 2                        Morocco                             NaN
# 3                  Sudoku (Free)                             NaN
# 4                   Senet Deluxe                             NaN
# ...                          ...                             ...
# 17002  Stack Puzzle : Rise Tower  Blast the cubes, solve puzzle!
# 17003                  EachOther                             NaN
# 17004         Rabbit Vs Tortoise                             NaN
# 17005                     FaTaLL                Most fun game!!!
# 17006   The Three Kingdoms :Bomb                             NaN
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...             4.000000
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...             3.500000
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...             3.000000
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...             3.500000
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...             3.500000
# ...                                                  ...                  ...
# 17002  https://is5-ssl.mzstatic.com/image/thumb/Purpl...             0.444608
# 17003  https://is2-ssl.mzstatic.com/image/thumb/Purpl...             0.444608
# 17004  https://is2-ssl.mzstatic.com/image/thumb/Purpl...             0.444608
# 17005  https://is1-ssl.mzstatic.com/image/thumb/Purpl...             0.444608
# 17006  https://is1-ssl.mzstatic.com/image/thumb/Purpl...             0.444608
#
#        User Rating Count  Price   In-app Purchases  \
# 0                   3553   2.99                NaN
# 1                    284   1.99                NaN
# 2                   8376   0.00                NaN
# 3                 190394   0.00                NaN
# 4                     28   2.99                NaN
# ...                  ...    ...                ...
# 17002                  1   0.00                NaN
# 17003                  1   0.00                NaN
# 17004                  1   0.00                NaN
# 17005                  1   0.00  9.99, 49.99, 3.99
# 17006                  1   0.00                NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year. Rated "Best ...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 17002  The goal is very simple, move the square horiz...
# 17003  Collect a score while you play!! By linking ch...
# 17004  "Rabbit Vs Tortoise is chess type cool simple ...
# 17005  Upgrade your character and use your skills to ...
# 17006  The protagonist uses the method of placing a b...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games          4
# 1              Kiss The Machine          4
# 2                   Bayou Games          4
# 3      Mighty Mighty Good Games          4
# 4               RoGame Software          4
# ...                         ...        ...
# 17002               Zhigang Pei          4
# 17003             Sultan Shindi          4
# 17004             Vishal Baldha          4
# 17005              Tayrem Games          4
# 17006              ming bo tang          4
#
#                                                Languages       Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568
# 1                                                     EN   12328960
# 2                                                     EN     674816
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024
# ...                                                  ...        ...
# 17002                                                 EN   64795648
# 17003                                                 EN  110341120
# 17004                                                 EN   23207936
# 17005                                                 EN  196750336
# 17006                                             EN, ZH   22952960
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 17002         Games  Games, Entertainment, Casual, Strategy
# 17003         Games                 Games, Family, Strategy
# 17004         Games                         Games, Strategy
# 17005         Games                 Games, Strategy, Action
# 17006         Games                 Games, Strategy, Puzzle
#
#       Original Release Date Current Version Release Date
# 0                2008/07/11                   30/05/2017
# 1                2008/07/11                   17/05/2018
# 2                2008/07/11                    5/09/2017
# 3                2008/07/23                   30/05/2017
# 4                2008/07/18                   22/07/2018
# ...                     ...                          ...
# 17002            2019/07/30                   30/07/2019
# 17003            2019/08/01                    1/08/2019
# 17004            2019/08/03                    3/08/2019
# 17005            2019/08/01                    1/08/2019
# 17006            2019/08/02                    2/08/2019
#
# [16827 rows x 18 columns]
